# %% [markdown]
# # Ensemble of CNNs for MNIST

# %% [markdown]
# Import Library

# %%
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
n_epochs = 2 # digunakan untuk menentukan banyaknya iterasi yang dibutuhkan pada training
batch_size_train = 64 # digunakan untuk menentukan banyaknya iterasi batch_size_train
batch_size_test = 1000 # digunakan untuk menentukan banyaknya nilai batch size data test
learning_rate = 0.03 # digunakan untuk menentukan nilai learning_rate
momentum = 0.7 # digunakan untuk menentukan nilai momentum
log_interval = 10 # digunakan untuk menilai batas waktu log_interval

random_seed = 1 # digunakan untuk menyimpan nilai status fungsi acak
torch.backends.cudnn.enabled = False # digunakan untuk menjalankan gpu, karena di google colab gpu sudah otomatis berjalan sehingga harus bernilai false
torch.manual_seed(random_seed) # digunakan untuk menyimpan status fungsi acak

# %%
train_loader = torch.utils.data.DataLoader( #digunakan untuk menyimpan data dengan DataLoader pada train
  torchvision.datasets.MNIST('/files/', train=True, download=True, # digunakan untuk memanggil data MNIST
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=batch_size_train, shuffle=True)

test_loader = torch.utils.data.DataLoader( #untuk menyimpan DataLoader pada test
  torchvision.datasets.MNIST('/files/', train=False, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=batch_size_test, shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /files/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting /files/MNIST/raw/train-images-idx3-ubyte.gz to /files/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /files/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting /files/MNIST/raw/train-labels-idx1-ubyte.gz to /files/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /files/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting /files/MNIST/raw/t10k-images-idx3-ubyte.gz to /files/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /files/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting /files/MNIST/raw/t10k-labels-idx1-ubyte.gz to /files/MNIST/raw

# %%
examples = enumerate(test_loader)
batch_idx, (example_data, example_targets) = next(examples)

# %%
# digunakan untuk memperlihatkan data test 1000 pada channel 1 dengan skala ukuran gambar 28x28
example_data.shape
# Out:
# torch.Size([1000, 1, 28, 28])

# %%
# digunakan untuk memperlihatkan nilai gambar asli
fig = plt.figure()
for i in range(6):
  plt.subplot(2,3,i+1)
  plt.tight_layout()
  plt.imshow(example_data[i][0], cmap='gray', interpolation='none')
  plt.title("Ground Truth: {}".format(example_targets[i]))
  plt.xticks([])
  plt.yticks([])
fig

# %%
class Net(nn.Module): # digunakan untuk membuat arsitektur nn.Module
    def __init__(self): # digunakan untuk menurunkan class
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d() # digunakan untuk mematikan sebagian nn yang mempunyai bobot yang sama
        self.fc1 = nn.Linear(320, 50) # nn.linear berisi 320 hidden layer dan 50 hidden layer
        self.fc2 = nn.Linear(50, 10) # nn.linear yang berisi 50 hidden layer serta 10 hidden layer
    def forward(self, x): # digunakan untuk menambahkan aktivasi relu, pooling, dan dropout
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x) # mengembalikan fungsi aktivasi F.log_softmax

# %%
class Net(nn.Module): # digunakan untuk membuat arsitektur nn.Module
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5) # nn.linear yang berisi 1 hidden layer serta 10 hidden layer
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5) # nn.linear yang berisi 10 hidden layer serta 20 hidden layer
        self.conv2_drop = nn.Dropout2d() # digunakan untuk mematikan sebagian nn yang mempunyai bobot yang sama
        self.fc1 = nn.Linear(320, 50) # disambungkan ke 320 hiden layer dan 50 hiden layer
        self.fc2 = nn.Linear(50, 10) # disambungkan ke 50 hiden layer dan disambungkan ke output 10 layer terakhir
    def forward(self, x): #untuk menambahkan aktivasi relu, pooling, dan dropout
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x) # mengembalikan fungsi aktivasi F.log_softmax

# %%
network = Net() # memanggil arsitektur yang telah dibuat
optimizer = optim.SGD(network.parameters(), lr=learning_rate, momentum=momentum) # algortima optimasi

# %%
train_losses = [] # di dalam train losses terdapat list kosong yang digunakan untuk menyimpan proses training loss
train_counter = [] #di dalam train_counter terdapat list kosong yang digunakan untuk menyimpan proses training counter
test_losses = [] #di dalam test_losses terdapat list kosong untuk menyimpan proses training test loss
test_counter = [i*len(train_loader.dataset) for i in range(n_epochs + 1)] # di dalam test_counter terdapat nilai variabel train_loader.dataset

# %%
# dilakukan proses training
def train(epoch): 
  network.train()
  for batch_idx, (data, target) in enumerate(train_loader):
    optimizer.zero_grad()
    output = network(data)
    loss = F.nll_loss(output, target)
    loss.backward()
    optimizer.step()
    if batch_idx % log_interval == 0:
      print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
        epoch, batch_idx * len(data), len(train_loader.dataset),
        100. * batch_idx / len(train_loader), loss.item()))
      train_losses.append(loss.item())
      train_counter.append(
        (batch_idx*64) + ((epoch-1)*len(train_loader.dataset)))

# %%
# dilakukan proses testing
def test(): 
  network.eval()
  test_loss = 0
  correct = 0
  with torch.no_grad():
    for data, target in test_loader:
      output = network(data)
      test_loss += F.nll_loss(output, target, size_average=False).item()
      pred = output.data.max(1, keepdim=True)[1]
      correct += pred.eq(target.data.view_as(pred)).sum()
  test_loss /= len(test_loader.dataset)
  test_losses.append(test_loss)
  print('\nTest set: Avg. loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
    test_loss, correct, len(test_loader.dataset),
    100. * correct / len(test_loader.dataset)))

# %%
# memanggil semua hasil training
test()
for epoch in range(1, n_epochs + 1):
  train(epoch)
  test()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Test set: Avg. loss: 2.3096, Accuracy: 924/10000 (9%)
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.325928
# Train Epoch: 1 [640/60000 (1%)]	Loss: 2.256222
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 2.165100
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 1.745337
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 1.449717
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 1.306892
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 0.992492
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 1.092531
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.991566
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 0.743223
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 0.988574
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 0.689782
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 0.911227
# Train Epoch: 1 [8320/60000 (14%)]	Loss: 0.647519
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 0.508461
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 0.671086
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.558270
# Train Epoch: 1 [10880/60000 (18%)]	Loss: 0.684302
# Train Epoch: 1 [11520/60000 (19%)]	Loss: 0.795890
# Train Epoch: 1 [12160/60000 (20%)]	Loss: 0.502983
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.536204
# Train Epoch: 1 [13440/60000 (22%)]	Loss: 0.546705
# Train Epoch: 1 [14080/60000 (23%)]	Loss: 0.694490
# Train Epoch: 1 [14720/60000 (25%)]	Loss: 0.300174
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.388818
# Train Epoch: 1 [16000/60000 (27%)]	Loss: 0.478812
# Train Epoch: 1 [16640/60000 (28%)]	Loss: 0.384041
# Train Epoch: 1 [17280/60000 (29%)]	Loss: 0.380986
# Train Epoch: 1 [17920/60000 (30%)]	Loss: 0.538491
# Train Epoch: 1 [18560/60000 (31%)]	Loss: 0.346792
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 0.754447
# Train Epoch: 1 [19840/60000 (33%)]	Loss: 0.507787
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.352838
# Train Epoch: 1 [21120/60000 (35%)]	Loss: 0.412337
# Train Epoch: 1 [21760/60000 (36%)]	Loss: 0.350277
# Train Epoch: 1 [22400/60000 (37%)]	Loss: 0.345183
# Train Epoch: 1 [23040/60000 (38%)]	Loss: 0.328633
# Train Epoch: 1 [23680/60000 (39%)]	Loss: 0.214852
# Train Epoch: 1 [24320/60000 (41%)]	Loss: 0.386281
# Train Epoch: 1 [24960/60000 (42%)]	Loss: 0.584709
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.357431
# Train Epoch: 1 [26240/60000 (44%)]	Loss: 0.444332
# Train Epoch: 1 [26880/60000 (45%)]	Loss: 0.370326
# Train Epoch: 1 [27520/60000 (46%)]	Loss: 0.310651
# Train Epoch: 1 [28160/60000 (47%)]	Loss: 0.396723
# Train Epoch: 1 [28800/60000 (48%)]	Loss: 0.258773
# Train Epoch: 1 [29440/60000 (49%)]	Loss: 0.422853
# Train Epoch: 1 [30080/60000 (50%)]	Loss: 0.464786
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.325571
# Train Epoch: 1 [31360/60000 (52%)]	Loss: 0.237351
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 0.493204
# Train Epoch: 1 [32640/60000 (54%)]	Loss: 0.173016
# Train Epoch: 1 [33280/60000 (55%)]	Loss: 0.305106
# Train Epoch: 1 [33920/60000 (57%)]	Loss: 0.226996
# Train Epoch: 1 [34560/60000 (58%)]	Loss: 0.308482
# Train Epoch: 1 [35200/60000 (59%)]	Loss: 0.367671
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.332756
# Train Epoch: 1 [36480/60000 (61%)]	Loss: 0.264816
# Train Epoch: 1 [37120/60000 (62%)]	Loss: 0.605168
# Train Epoch: 1 [37760/60000 (63%)]	Loss: 0.522411
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.404053
# Train Epoch: 1 [39040/60000 (65%)]	Loss: 0.419704
# Train Epoch: 1 [39680/60000 (66%)]	Loss: 0.373623
# Train Epoch: 1 [40320/60000 (67%)]	Loss: 0.235803
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.163119
# Train Epoch: 1 [41600/60000 (69%)]	Loss: 0.199682
# Train Epoch: 1 [42240/60000 (70%)]	Loss: 0.222175
# Train Epoch: 1 [42880/60000 (71%)]	Loss: 0.262011
# Train Epoch: 1 [43520/60000 (72%)]	Loss: 0.297799
# Train Epoch: 1 [44160/60000 (74%)]	Loss: 0.296115
# Train Epoch: 1 [44800/60000 (75%)]	Loss: 0.235745
# Train Epoch: 1 [45440/60000 (76%)]	Loss: 0.304819
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.306815
# Train Epoch: 1 [46720/60000 (78%)]	Loss: 0.235558
# Train Epoch: 1 [47360/60000 (79%)]	Loss: 0.408271
# Train Epoch: 1 [48000/60000 (80%)]	Loss: 0.337805
# Train Epoch: 1 [48640/60000 (81%)]	Loss: 0.192341
# Train Epoch: 1 [49280/60000 (82%)]	Loss: 0.217386
# Train Epoch: 1 [49920/60000 (83%)]	Loss: 0.259144
# Train Epoch: 1 [50560/60000 (84%)]	Loss: 0.386569
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.572474
# Train Epoch: 1 [51840/60000 (86%)]	Loss: 0.417059
# Train Epoch: 1 [52480/60000 (87%)]	Loss: 0.535646
# Train Epoch: 1 [53120/60000 (88%)]	Loss: 0.410125
# Train Epoch: 1 [53760/60000 (90%)]	Loss: 0.314969
# Train Epoch: 1 [54400/60000 (91%)]	Loss: 0.397598
# Train Epoch: 1 [55040/60000 (92%)]	Loss: 0.268540
# Train Epoch: 1 [55680/60000 (93%)]	Loss: 0.176565
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.315391
# Train Epoch: 1 [56960/60000 (95%)]	Loss: 0.216078
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 0.314053
# Train Epoch: 1 [58240/60000 (97%)]	Loss: 0.138667
# Train Epoch: 1 [58880/60000 (98%)]	Loss: 0.451300
# Train Epoch: 1 [59520/60000 (99%)]	Loss: 0.176942
#
# Test set: Avg. loss: 0.0947, Accuracy: 9715/10000 (97%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.283137
# Train Epoch: 2 [640/60000 (1%)]	Loss: 0.309761
# Train Epoch: 2 [1280/60000 (2%)]	Loss: 0.290663
# Train Epoch: 2 [1920/60000 (3%)]	Loss: 0.314347
# Train Epoch: 2 [2560/60000 (4%)]	Loss: 0.293006
# Train Epoch: 2 [3200/60000 (5%)]	Loss: 0.320863
# Train Epoch: 2 [3840/60000 (6%)]	Loss: 0.208892
# Train Epoch: 2 [4480/60000 (7%)]	Loss: 0.514121
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.245624
# Train Epoch: 2 [5760/60000 (10%)]	Loss: 0.659950
# Train Epoch: 2 [6400/60000 (11%)]	Loss: 0.307476
# Train Epoch: 2 [7040/60000 (12%)]	Loss: 0.299181
# Train Epoch: 2 [7680/60000 (13%)]	Loss: 0.273986
# Train Epoch: 2 [8320/60000 (14%)]	Loss: 0.267013
# Train Epoch: 2 [8960/60000 (15%)]	Loss: 0.133612
# Train Epoch: 2 [9600/60000 (16%)]	Loss: 0.201546
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.282870
# Train Epoch: 2 [10880/60000 (18%)]	Loss: 0.287118
# Train Epoch: 2 [11520/60000 (19%)]	Loss: 0.442776
# Train Epoch: 2 [12160/60000 (20%)]	Loss: 0.154442
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.285664
# Train Epoch: 2 [13440/60000 (22%)]	Loss: 0.373662
# Train Epoch: 2 [14080/60000 (23%)]	Loss: 0.276836
# Train Epoch: 2 [14720/60000 (25%)]	Loss: 0.212354
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.195123
# Train Epoch: 2 [16000/60000 (27%)]	Loss: 0.378778
# Train Epoch: 2 [16640/60000 (28%)]	Loss: 0.489521
# Train Epoch: 2 [17280/60000 (29%)]	Loss: 0.114853
# Train Epoch: 2 [17920/60000 (30%)]	Loss: 0.353009
# Train Epoch: 2 [18560/60000 (31%)]	Loss: 0.153241
# Train Epoch: 2 [19200/60000 (32%)]	Loss: 0.290364
# Train Epoch: 2 [19840/60000 (33%)]	Loss: 0.157914
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.333092
# Train Epoch: 2 [21120/60000 (35%)]	Loss: 0.275281
# Train Epoch: 2 [21760/60000 (36%)]	Loss: 0.311886
# Train Epoch: 2 [22400/60000 (37%)]	Loss: 0.395097
# Train Epoch: 2 [23040/60000 (38%)]	Loss: 0.296657
# Train Epoch: 2 [23680/60000 (39%)]	Loss: 0.153310
# Train Epoch: 2 [24320/60000 (41%)]	Loss: 0.309133
# Train Epoch: 2 [24960/60000 (42%)]	Loss: 0.445149
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.383790
# Train Epoch: 2 [26240/60000 (44%)]	Loss: 0.203119
# Train Epoch: 2 [26880/60000 (45%)]	Loss: 0.197755
# Train Epoch: 2 [27520/60000 (46%)]	Loss: 0.442456
# Train Epoch: 2 [28160/60000 (47%)]	Loss: 0.119845
# Train Epoch: 2 [28800/60000 (48%)]	Loss: 0.241595
# Train Epoch: 2 [29440/60000 (49%)]	Loss: 0.170024
# Train Epoch: 2 [30080/60000 (50%)]	Loss: 0.181443
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.241460
# Train Epoch: 2 [31360/60000 (52%)]	Loss: 0.105336
# Train Epoch: 2 [32000/60000 (53%)]	Loss: 0.180389
# Train Epoch: 2 [32640/60000 (54%)]	Loss: 0.288231
# Train Epoch: 2 [33280/60000 (55%)]	Loss: 0.253810
# Train Epoch: 2 [33920/60000 (57%)]	Loss: 0.333432
# Train Epoch: 2 [34560/60000 (58%)]	Loss: 0.190318
# Train Epoch: 2 [35200/60000 (59%)]	Loss: 0.374049
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.205636
# Train Epoch: 2 [36480/60000 (61%)]	Loss: 0.161360
# Train Epoch: 2 [37120/60000 (62%)]	Loss: 0.258919
# Train Epoch: 2 [37760/60000 (63%)]	Loss: 0.211006
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.224284
# Train Epoch: 2 [39040/60000 (65%)]	Loss: 0.297590
# Train Epoch: 2 [39680/60000 (66%)]	Loss: 0.270943
# Train Epoch: 2 [40320/60000 (67%)]	Loss: 0.209042
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.403558
# Train Epoch: 2 [41600/60000 (69%)]	Loss: 0.242100
# Train Epoch: 2 [42240/60000 (70%)]	Loss: 0.203032
# Train Epoch: 2 [42880/60000 (71%)]	Loss: 0.300701
# Train Epoch: 2 [43520/60000 (72%)]	Loss: 0.201034
# Train Epoch: 2 [44160/60000 (74%)]	Loss: 0.281858
# Train Epoch: 2 [44800/60000 (75%)]	Loss: 0.191764
# Train Epoch: 2 [45440/60000 (76%)]	Loss: 0.238250
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.262187
# Train Epoch: 2 [46720/60000 (78%)]	Loss: 0.311074
# Train Epoch: 2 [47360/60000 (79%)]	Loss: 0.345729
# Train Epoch: 2 [48000/60000 (80%)]	Loss: 0.160936
# Train Epoch: 2 [48640/60000 (81%)]	Loss: 0.118293
# Train Epoch: 2 [49280/60000 (82%)]	Loss: 0.371619
# Train Epoch: 2 [49920/60000 (83%)]	Loss: 0.071172
# Train Epoch: 2 [50560/60000 (84%)]	Loss: 0.159329
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.279601
# Train Epoch: 2 [51840/60000 (86%)]	Loss: 0.352354
# Train Epoch: 2 [52480/60000 (87%)]	Loss: 0.388864
# Train Epoch: 2 [53120/60000 (88%)]	Loss: 0.218217
# Train Epoch: 2 [53760/60000 (90%)]	Loss: 0.312699
# Train Epoch: 2 [54400/60000 (91%)]	Loss: 0.529709
# Train Epoch: 2 [55040/60000 (92%)]	Loss: 0.190691
# Train Epoch: 2 [55680/60000 (93%)]	Loss: 0.139743
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.294837
# Train Epoch: 2 [56960/60000 (95%)]	Loss: 0.330736
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 0.355116
# Train Epoch: 2 [58240/60000 (97%)]	Loss: 0.073890
# Train Epoch: 2 [58880/60000 (98%)]	Loss: 0.170424
# Train Epoch: 2 [59520/60000 (99%)]	Loss: 0.365832
#
# Test set: Avg. loss: 0.0679, Accuracy: 9802/10000 (98%)

# %%
# digunakan untuk visualisasi plot
fig = plt.figure()
plt.plot(train_counter, train_losses, color='blue')
plt.scatter(test_counter, test_losses, color='red')
plt.legend(['Train Loss', 'Test Loss'], loc='upper right')
plt.xlabel('number of training examples seen')
plt.ylabel('negative log likelihood loss')
fig
